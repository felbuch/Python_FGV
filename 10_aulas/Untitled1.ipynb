# %%
import pandas as pd

# %%
netflix = pd.read_csv('https://raw.githubusercontent.com/ygterl/EDA-Netflix-2020-in-R/master/netflix_titles.csv')

# %%
netflix.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
netflix.type.value_counts()
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-bdbeb2498c9a> in <module>
# ----> 1 from titanic_visualizations import survival_stats
#
# ModuleNotFoundError: No module named 'titanic_visualizations'

# %%
movies = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/movie_ratings.csv')

# %%
movies.head()
# Out:
#    Toy.Story  Jumanji  Grumpier.Old.Men  Waiting.to.Exhale  \
# 0        NaN      NaN               NaN                NaN
# 1        5.0      NaN               2.0                NaN
# 2        NaN      NaN               NaN                NaN
# 3        NaN      NaN               NaN                NaN
# 4        4.0      NaN               NaN                NaN
#
#    Father.of.the.Bride.Part.II  Heat  Sabrina  Tom.and.Huck  Sudden.Death  \
# 0                          NaN   NaN      NaN           NaN           NaN
# 1                          3.0   NaN      NaN           NaN           NaN
# 2                          3.0   NaN      3.0           NaN           NaN
# 3                          NaN   NaN      NaN           NaN           NaN
# 4                          NaN   NaN      NaN           NaN           NaN
#
#    GoldenEye  ...  Circle  The.Measure.of.a.Man  Bone.Tomahawk  \
# 0        NaN  ...     NaN                   NaN            NaN
# ...

# %%
bank = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/bank-full.csv',
                  sep = ';')

# %%
bank.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...
